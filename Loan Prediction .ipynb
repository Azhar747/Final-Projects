# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("E:\Datatrained final Projects\loan_prediction.csv")

# %%
df.shape
# Out:
# (614, 13)

# %% [markdown]
# So there are 614 rows and 13 columns

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# There are null values present

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# So with the above report we can note that Applicant Maximum income is j81000 and min is 150  and Maximum Loan Amount is 700 and min 9

# %%
sns.countplot(df["Gender"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# So there are more number of male when compared to female

# %%
sns.countplot(df["Married"])
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %% [markdown]
# So most of them are married

# %%
sns.countplot(df["Dependents"])
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %% [markdown]
# So there are four values of Dependents

# %%
sns.countplot(df["Education"])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# So in this dataset there are two types of one is Graduate and other is not graduate and most of them are grduates

# %%
sns.countplot(df["Self_Employed"])
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %% [markdown]
# Most of the applicants not self employed

# %%
sns.countplot(df["Property_Area"])
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %% [markdown]
# Property Area has Three values Urban , Rural and Semiurban and most them are Semiurban

# %%
sns.countplot(df["Loan_Status"])
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# with above graph we can understand that most of

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# We can drop loan ID since it is not that useful

# %%
df=df.drop("Loan_ID",axis=1)

# %%
sns.distplot(df['ApplicantIncome'])
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='Density'>

# %% [markdown]
# The Graph is skewed

# %%
sns.distplot(df['CoapplicantIncome'])
# Out:
# <AxesSubplot:xlabel='CoapplicantIncome', ylabel='Density'>

# %%
df.head(20)
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male      No          0      Graduate            No             5849
# 1     Male     Yes          1      Graduate            No             4583
# 2     Male     Yes          0      Graduate           Yes             3000
# 3     Male     Yes          0  Not Graduate            No             2583
# 4     Male      No          0      Graduate            No             6000
# 5     Male     Yes          2      Graduate           Yes             5417
# 6     Male     Yes          0  Not Graduate            No             2333
# 7     Male     Yes         3+      Graduate            No             3036
# 8     Male     Yes          2      Graduate            No             4006
# 9     Male     Yes          1      Graduate            No            12841
# 10    Male     Yes          2      Graduate            No             3200
# ...

# %% [markdown]
# The graph is skewed

# %% [markdown]
# ## Encoding The Target Column

# %%
Loan_Sta_dumm=pd.get_dummies(df["Loan_Status"],drop_first=True) ## Here Y ie Yes is 1 and N is no is 0

# %%
df=pd.concat([df,Loan_Sta_dumm],axis=1)

# %%
df=df.drop(["Loan_Status"],axis=1)

# %%
df.rename(columns = {'Y':'Loan_Status'}, inplace = True)

# %%
df.head(20)
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male      No          0      Graduate            No             5849
# 1     Male     Yes          1      Graduate            No             4583
# 2     Male     Yes          0      Graduate           Yes             3000
# 3     Male     Yes          0  Not Graduate            No             2583
# 4     Male      No          0      Graduate            No             6000
# 5     Male     Yes          2      Graduate           Yes             5417
# 6     Male     Yes          0  Not Graduate            No             2333
# 7     Male     Yes         3+      Graduate            No             3036
# 8     Male     Yes          2      Graduate            No             4006
# 9     Male     Yes          1      Graduate            No            12841
# 10    Male     Yes          2      Graduate            No             3200
# ...

# %% [markdown]
# ## Handling NULL values

# %%
df.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df=df.dropna() # Since the values are less we will be dropping the null vaules

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# So all the null values has been removed

# %%
df["Loan_Status"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here 1 means Loan will be approved 0 means loan will not be approved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             480 non-null    object
#  1   Married            480 non-null    object
#  2   Dependents         480 non-null    object
#  3   Education          480 non-null    object
#  4   Self_Employed      480 non-null    object
#  5   ApplicantIncome    480 non-null    int64
#  6   CoapplicantIncome  480 non-null    float64
#  7   LoanAmount         480 non-null    float64
#  8   Loan_Amount_Term   480 non-null    float64
#  9   Credit_History     480 non-null    float64
#  10  Property_Area      480 non-null    object
#  11  Loan_Status        480 non-null    uint8
# dtypes: float64(4), int64(1), object(6), uint8(1)
# memory usage: 45.5+ KB

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x="Loan_Status",y="ApplicantIncome",data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %%
sns.countplot(x='Loan_Status', hue='Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# With this Graph we can understand the If you are male the most of chances are there for the loan getting approved

# %%
sns.countplot(x='Loan_Status', hue='Married', data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# Chances of getting the loan approved is more for the persons who are married

# %%
sns.countplot(x='Loan_Status', hue='Dependents', data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# Chances of getting the loan approved is more for 0 dependents and lowest for 3+

# %% [markdown]
# Since 3+ is not the numerical value we will be replacing it with 4

# %%
df=df.replace(to_replace="3+",value=4)

# %%
sns.countplot(x='Loan_Status', hue='Dependents', data=df)  ## So know the value has been replaced by 4
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status', hue='Education', data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# Chances for loan getting approved is more for Graduate

# %%
sns.countplot(x='Loan_Status', hue='Property_Area', data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# So for Semiurban the chances of loan getting approved is more

# %%
sns.scatterplot(x='Loan_Status',y='ApplicantIncome',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %%
sns.scatterplot(x='Loan_Status',y='LoanAmount',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='LoanAmount'>

# %%
sns.scatterplot(x='Loan_Status',y='LoanAmount',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='LoanAmount'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             480 non-null    object
#  1   Married            480 non-null    object
#  2   Dependents         480 non-null    object
#  3   Education          480 non-null    object
#  4   Self_Employed      480 non-null    object
#  5   ApplicantIncome    480 non-null    int64
#  6   CoapplicantIncome  480 non-null    float64
#  7   LoanAmount         480 non-null    float64
#  8   Loan_Amount_Term   480 non-null    float64
#  9   Credit_History     480 non-null    float64
#  10  Property_Area      480 non-null    object
#  11  Loan_Status        480 non-null    uint8
# dtypes: float64(4), int64(1), object(6), uint8(1)
# memory usage: 61.6+ KB

# %%
df["Dependents"].value_counts()
# Out:
# 0    274
# 2     85
# 1     80
# 4     41
# Name: Dependents, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Male      394
# Female     86
# Name: Gender, dtype: int64

# %%
df["Dependents"] = pd.to_numeric(df["Dependents"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             480 non-null    object
#  1   Married            480 non-null    object
#  2   Dependents         480 non-null    int64
#  3   Education          480 non-null    object
#  4   Self_Employed      480 non-null    object
#  5   ApplicantIncome    480 non-null    int64
#  6   CoapplicantIncome  480 non-null    float64
#  7   LoanAmount         480 non-null    float64
#  8   Loan_Amount_Term   480 non-null    float64
#  9   Credit_History     480 non-null    float64
#  10  Property_Area      480 non-null    object
#  11  Loan_Status        480 non-null    uint8
# dtypes: float64(4), int64(2), object(5), uint8(1)
# memory usage: 61.6+ KB

# %% [markdown]
# ## Encoding the features

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    else:
        df[column]=LabelEncoder().fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             480 non-null    int32
#  1   Married            480 non-null    int32
#  2   Dependents         480 non-null    int64
#  3   Education          480 non-null    int32
#  4   Self_Employed      480 non-null    int32
#  5   ApplicantIncome    480 non-null    int64
#  6   CoapplicantIncome  480 non-null    float64
#  7   LoanAmount         480 non-null    float64
#  8   Loan_Amount_Term   480 non-null    float64
#  9   Credit_History     480 non-null    float64
#  10  Property_Area      480 non-null    int32
#  11  Loan_Status        480 non-null    int64
# dtypes: float64(4), int32(5), int64(3)
# memory usage: 55.5 KB

# %%
df["Gender"].value_counts()
# Out:
# 1    394
# 0     86
# Name: Gender, dtype: int64

# %% [markdown]
# ## Checking the outliers

# %%
collist=df.columns.values

# %%
ncol=6
nrow=6
plt.figure(figsize=(5*nrow,6*ncol),dpi=300)
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient="v")

# %%
#1st quantile
q1=df.quantile(0.25)

# %%
#3rd quantile
q3=df.quantile(0.75)

# %%
#IQR
IQR=q3-q1

# %%
CoapplicantIncome_high=q3.CoapplicantIncome+1.5*IQR.CoapplicantIncome

# %%
CoapplicantIncome_high
# Out:
# 5633.125

# %%
index=np.where(df['CoapplicantIncome']>CoapplicantIncome_high)
index
# Out:
# (array([  8,  10,  28,  72,  92, 100, 137, 140, 187, 198, 269, 289, 312,
#         326, 400, 409, 454], dtype=int64),)

# %%
df=df.drop(df.index[index])

# %%
df.reset_index(inplace = True, drop = True)

# %%
LoanAmount_high=q3.LoanAmount+1.5*IQR.LoanAmount
index=np.where(df['LoanAmount']>LoanAmount_high)
index
# Out:
# (array([ 15,  24,  38,  50, 114, 172, 193, 210, 234, 243, 244, 260, 275,
#         283, 306, 366, 386, 394, 402, 422, 454], dtype=int64),)

# %%
df=df.drop(df.index[index])
df.reset_index(inplace = True, drop = True)

# %%
df.shape
# Out:
# (442, 12)

# %% [markdown]
# So we have remove the outliers

# %% [markdown]
# ## Checking the Correration

# %%
corre=df.corr()

# %%
plt.figure(figsize=(15,7))
sns.heatmap(corre,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The correration looks fine

# %%
X=df.drop("Loan_Status",axis=1)
y=df["Loan_Status"]

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
X_scalar=scalar.fit_transform(X)

# %% [markdown]
# ## Train Test split

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X_scalar, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
Logi_reg=LogisticRegression()

# %%
Logi_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=Logi_reg.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[22, 23],
#        [ 3, 98]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.49      0.63        45
#            1       0.81      0.97      0.88       101
#
#     accuracy                           0.82       146
#    macro avg       0.84      0.73      0.76       146
# weighted avg       0.83      0.82      0.80       146

# %%
logi_accuracy=accuracy_score(y_test, y_pred)

# %%
logi_accuracy
# Out:
# 0.821917808219178

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(Logi_reg,X_scalar,y,cv=5).mean()
# Out:
# 0.8213483146067416

# %% [markdown]
# ## Hyperpameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [    
    {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }
]

# %%
clf = GridSearchCV(Logi_reg, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
clf = GridSearchCV(Logi_reg, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
clf.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                           'max_iter': [100, 1000, 2500, 5000],
#                           'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                           'solver': ['lbfgs', 'newton-cg', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=True)

# %%
clf.best_params_
# Out:
# {'C': 0.0001, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
Logi_reg_CV=LogisticRegression(C=0.0001,max_iter=100,penalty="l2",solver='liblinear')

# %%
Logi_reg_CV.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.0001, solver='liblinear')

# %%
y_pred_CV=Logi_reg_CV.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
confusion_matrix(y_test, y_pred_CV)
# Out:
# array([[22, 23],
#        [ 3, 98]], dtype=int64)

# %%
print(classification_report(y_test, y_pred_CV))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.49      0.63        45
#            1       0.81      0.97      0.88       101
#
#     accuracy                           0.82       146
#    macro avg       0.84      0.73      0.76       146
# weighted avg       0.83      0.82      0.80       146

# %%
logi_accuracy_CV=accuracy_score(y_test, y_pred_CV)

# %% [markdown]
# Accuracy after Hyperparameter tuning

# %%
logi_accuracy_CV
# Out:
# 0.821917808219178

# %% [markdown]
# ## Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_Ran=model.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
confusion_matrix(y_test,y_pred_Ran)
# Out:
# array([[23, 22],
#        [ 5, 96]], dtype=int64)

# %%
print(classification_report(y_test,y_pred_Ran))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.51      0.63        45
#            1       0.81      0.95      0.88       101
#
#     accuracy                           0.82       146
#    macro avg       0.82      0.73      0.75       146
# weighted avg       0.82      0.82      0.80       146

# %%
model_acc=accuracy_score(y_test,y_pred_Ran)

# %%
model_acc
# Out:
# 0.815068493150685

# %% [markdown]
# ## Cross Validation Score

# %%
cross_val_score(model,X_scalar,y,cv=5).mean()
# Out:
# 0.8009448416751788

# %% [markdown]
# ## Hyper Paremter Tuning

# %%
n_estimators = [100, 300, 500, 800, 1200]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100]
max_features=["auto","sqrt"]
bootstrap=[True,False]
min_samples_leaf = [1, 2, 5, 10]

# %%
param_grid ={"n_estimators":n_estimators,
              "max_depth": max_depth,  
              "min_samples_split":min_samples_split, 
             "min_samples_leaf":min_samples_leaf, 
             "bootstrap":bootstrap, 
            "max_features":max_features}

print(param_grid)
# Out:
# {'n_estimators': [100, 300, 500, 800, 1200], 'max_depth': [5, 8, 15, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10], 'bootstrap': [True, False], 'max_features': ['auto', 'sqrt']}

# %%
rf_grid=GridSearchCV(estimator=model,param_grid=param_grid,cv=3,n_jobs=-1,verbose=2)

# %%
#rf_grid.fit(X_train,y_train)

# %%
#rf_grid.best_params_

# %%
model_CV=RandomForestClassifier(n_estimators=100,max_depth=25, min_samples_split=10,min_samples_leaf=1,bootstrap=True,max_features='auto')

# %%
model_CV.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=25, min_samples_split=10)

# %% [markdown]
# ## Model Evaluation

# %%
y_pred_Ran_CV=model_CV.predict(X_test)

# %%
acc_score_ran=accuracy_score(y_pred_Ran_CV,y_test)

# %%
acc_score_ran
# Out:
# 0.8287671232876712

# %%
cross_val_score(model_CV,X_scalar,y,cv=5).mean()
# Out:
# 0.8032431052093972

# %%
confusion_matrix(y_pred_Ran_CV,y_test)
# Out:
# array([[23,  3],
#        [22, 98]], dtype=int64)

# %%
print(classification_report(y_pred_Ran_CV,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.88      0.65        26
#            1       0.97      0.82      0.89       120
#
#     accuracy                           0.83       146
#    macro avg       0.74      0.85      0.77       146
# weighted avg       0.89      0.83      0.84       146

# %% [markdown]
# ## Decition Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc_model=DecisionTreeClassifier()

# %%
dtc_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dc=dtc_model.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
acc_score_dc=accuracy_score(y_pred_dc,y_test)

# %%
acc_score_dc
# Out:
# 0.6643835616438356

# %%
print(classification_report(y_pred_dc,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.47      0.53        60
#            1       0.68      0.80      0.74        86
#
#     accuracy                           0.66       146
#    macro avg       0.65      0.63      0.64       146
# weighted avg       0.66      0.66      0.65       146

# %% [markdown]
# ## Hyperparameter tuning of Decision tree

# %%
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
grid_search_dc = GridSearchCV(estimator=dtc_model, param_grid=params,cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
grid_search_dc.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
grid_search_dc.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5}

# %%
dtc_model_CV=DecisionTreeClassifier(max_depth=2,min_samples_leaf=5,criterion='gini')

# %%
dtc_model_CV.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=5)

# %% [markdown]
# ## Model Evaluation

# %%
y_pred_dc_cv=dtc_model_CV.predict(X_test)

# %%
acc_score_dc_cv=accuracy_score(y_pred_dc_cv,y_test)

# %%
acc_score_dc_cv
# Out:
# 0.8356164383561644

# %%
print(classification_report(y_pred_dc_cv,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.96      0.65        23
#            1       0.99      0.81      0.89       123
#
#     accuracy                           0.84       146
#    macro avg       0.74      0.88      0.77       146
# weighted avg       0.91      0.84      0.85       146

# %% [markdown]
# ## Auc and Roc Curves to select the best model

# %%
from sklearn.metrics import roc_curve,auc

# %%
#For logistic Regression without Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test, y_pred)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Logistic Regression Without Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Logistic Regression Without Hyperparmeter tuning')

# %%
#For logistic Regression with Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test, y_pred_CV)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Logistic Regression With Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Logistic Regression With Hyperparmeter tuning')

# %%
#For Random Forest without Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test,y_pred_Ran)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Random forest Without Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Random forest Without Hyperparmeter tuning')

# %%
#For Random Forest with Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_pred_Ran_CV,y_test)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Random forest With Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Random forest With Hyperparmeter tuning')

# %%
#For Decision tree without Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_pred_dc,y_test)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Decision tree Without Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Decision tree Without Hyperparmeter tuning')

# %%
#For Decision tree with Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_pred_dc_cv,y_test)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Decision tree With Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Decision tree With Hyperparmeter tuning')

# %% [markdown]
# ## Here we can observe Random Forest with Hyperparameter tuning is the best model

# %% [markdown]
# # Saving the model for future use

# %%
import pickle

# %%
filename = 'Loan Prediction.sav'
pickle.dump(model_CV, open(filename, 'wb'))
