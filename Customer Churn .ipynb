# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Understanding the DATA

# %%
df=pd.read_csv("E:\Datatrained final Projects\Telecom_customer_churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# Here we can observe that ther are 7043 rows and 21 cololumns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# There is categorical data present we will deal with it

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# There are no missing values

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# There al 7043 rows in senir Citizen , tenure has max as 72 months  and min is 29 months, monthly charges max 118, and min is 35

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.drop("customerID",axis=1,inplace=True) ## Customer ID is not that useful we will drop it

# %%
df.shape ## So now we have left with 20 columns
# Out:
# (7043, 20)

# %%
df["Churn"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# So customers who didnot churn or didn't stop doing business is 5174 and who churn ie leave the company is 1869

# %%
sns.countplot(df["Churn"])
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %% [markdown]
# The above figure represents the graphicial representation of Churn

# %%
sns.countplot(df["gender"])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# So there are almost equal Female and Male

# %%
sns.histplot(x=df["SeniorCitizen"])
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='Count'>

# %% [markdown]
# So there very less number of Senior Citizen in the dataset

# %%
sns.countplot(df["Dependents"])
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
sns.histplot(x=df["tenure"])
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Count'>

# %% [markdown]
# So the tenure range from 0 to 70

# %%
sns.countplot(df["gender"],hue=df["Churn"])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# With this graph we cannot analyse anything since the graph is equal between Male and Female

# %%
sns.countplot(df["Partner"],hue=df["Churn"])
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='count'>

# %% [markdown]
# So this graph we can understand that the peopel who are had the partner had not left the company than who did not have partner

# %%
sns.countplot(df["TechSupport"],hue=df["Churn"])
# Out:
# <AxesSubplot:xlabel='TechSupport', ylabel='count'>

# %% [markdown]
# So the peope who didnot recieve the tech support left the company .

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
sns.histplot(x=df["MonthlyCharges"],hue=df["Churn"])
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Count'>

# %% [markdown]
# So here we can see that most of the persons who are not leaving the company has the monthly charges of almost 20  and also we can see that the perons who are leaving the company has the changes 70 to 100

# %%
sns.histplot(x=df["tenure"],hue=df["Churn"])
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Count'>

# %% [markdown]
# So most of the persons who are has churn is 0 moths and the persons who did not churn has the count of 70 so the persons who churn has less tenure and the persons who didnot churn has more tenure

# %%
sns.countplot(df["StreamingTV"],hue=df["Churn"])
# Out:
# <AxesSubplot:xlabel='StreamingTV', ylabel='count'>

# %% [markdown]
# So graph has almost equal distribution

# %% [markdown]
# ## Encoding the Categorical Data

# %%
dumm=pd.get_dummies(df["Churn"],drop_first=True)

# %%
df=pd.concat([df,dumm],axis=1)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# ...

# %%
df.drop("Churn",axis=1,inplace=True)

# %%
df.rename({"Yes":"Churn"},axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df["Churn"].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %% [markdown]
# ## Encoding Other Column using Lable Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    else:
        df[column]=LabelEncoder().fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int32
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int32
#  3   Dependents        7043 non-null   int32
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int32
#  6   MultipleLines     7043 non-null   int32
#  7   InternetService   7043 non-null   int32
#  8   OnlineSecurity    7043 non-null   int32
#  9   OnlineBackup      7043 non-null   int32
#  10  DeviceProtection  7043 non-null   int32
#  11  TechSupport       7043 non-null   int32
#  12  StreamingTV       7043 non-null   int32
#  13  StreamingMovies   7043 non-null   int32
#  14  Contract          7043 non-null   int32
#  15  PaperlessBilling  7043 non-null   int32
# ...

# %%
df["Churn"].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %% [markdown]
# The datset is imbalanced So we need to treate it we will treate it using Smote technique

# %% [markdown]
# ## Checking the Outliers

# %%
collist=df.columns.values

# %%
ncol=6
nrow=6
plt.figure(figsize=(5*nrow,6*ncol),dpi=300)
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient="v")

# %% [markdown]
# There are almost no outliers

# %% [markdown]
# ## Checking the Correlation

# %%
corre=df.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corre,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# So correlation seems to okay

# %%
X=df.drop("Churn",axis=1)

# %%
y=df["Churn"]

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
X_scalar=scalar.fit_transform(X)

# %% [markdown]
# ## Performing train test split

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X_scalar, y, test_size=0.33, random_state=42)

# %%
print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions X_test dataset: ", X_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
# Out:
# Number transactions X_train dataset:  (4718, 19)
# Number transactions y_train dataset:  (4718,)
# Number transactions X_test dataset:  (2325, 19)
# Number transactions y_test dataset:  (2325,)

# %%
df["Churn"].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
import imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))
# Out:
# Before OverSampling, counts of label '1': 1241
# Before OverSampling, counts of label '0': 3477

# %%
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_train, y_train)

print('After OverSampling, the shape of train_X: {}'.format(X_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_res==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_res==0)))
# Out:
# After OverSampling, the shape of train_X: (6954, 19)
# After OverSampling, the shape of train_y: (6954,)
#
# After OverSampling, counts of label '1': 3477
# After OverSampling, counts of label '0': 3477

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
Logi_reg=LogisticRegression()

# %%
Logi_reg.fit(X_res,y_res)
# Out:
# LogisticRegression()

# %%
y_pred=Logi_reg.predict(X_test)

# %%
## Logistic Regression Model Evaluation

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1236,  461],
#        [ 111,  517]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81      1697
#            1       0.53      0.82      0.64       628
#
#     accuracy                           0.75      2325
#    macro avg       0.72      0.78      0.73      2325
# weighted avg       0.81      0.75      0.77      2325

# %%
logi_accuracy=accuracy_score(y_test, y_pred)

# %%
logi_accuracy
# Out:
# 0.753978494623656

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(Logi_reg,X_scalar,y,cv=5).mean()
# Out:
# 0.8033525348409574

# %% [markdown]
# ## Hyperparmater Tuning of Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [    
    {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }
]

# %%
clf = GridSearchCV(Logi_reg, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
clf.fit(X_res,y_res)
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                           'max_iter': [100, 1000, 2500, 5000],
#                           'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                           'solver': ['lbfgs', 'newton-cg', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=True)

# %%
clf.best_params_
# Out:
# {'C': 4.281332398719396, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}

# %%
Logi_reg_CV=LogisticRegression(C=4.281332398719396,max_iter=100,penalty="l1",solver='saga')

# %%
Logi_reg_CV.fit(X_res,y_res)
# Out:
# LogisticRegression(C=4.281332398719396, penalty='l1', solver='saga')

# %%
y_pred_CV=Logi_reg_CV.predict(X_test)

# %%
confusion_matrix(y_test, y_pred_CV)
# Out:
# array([[1237,  460],
#        [ 111,  517]], dtype=int64)

# %%
print(classification_report(y_test, y_pred_CV))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81      1697
#            1       0.53      0.82      0.64       628
#
#     accuracy                           0.75      2325
#    macro avg       0.72      0.78      0.73      2325
# weighted avg       0.81      0.75      0.77      2325

# %%
logi_accuracy_CV=accuracy_score(y_test, y_pred_CV)

# %%
logi_accuracy_CV
# Out:
# 0.7544086021505376

# %% [markdown]
# ## Cross Validation

# %%
cross_val_score(Logi_reg_CV,X_scalar,y,cv=5).mean()
# Out:
# 0.8033525348409574

# %% [markdown]
# ## Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
model.fit(X_res,y_res)
# Out:
# RandomForestClassifier()

# %%
y_pred_Ran=model.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
y_pred_Ran=model.predict(X_test)

# %%
confusion_matrix(y_test,y_pred_Ran)
# Out:
# array([[1442,  255],
#        [ 254,  374]], dtype=int64)

# %%
print(classification_report(y_test,y_pred_Ran))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1697
#            1       0.59      0.60      0.60       628
#
#     accuracy                           0.78      2325
#    macro avg       0.72      0.72      0.72      2325
# weighted avg       0.78      0.78      0.78      2325

# %%
model_acc=accuracy_score(y_test,y_pred_Ran)

# %%
model_acc
# Out:
# 0.7810752688172043

# %% [markdown]
# ## Hyperparmaeter tuning of Random forest

# %%
n_estimators = [100, 300, 500, 800, 1200]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100]
max_features=["auto","sqrt"]
bootstrap=[True,False]
min_samples_leaf = [1, 2, 5, 10]

# %%
param_grid ={"n_estimators":n_estimators,
              "max_depth": max_depth,  
              "min_samples_split":min_samples_split, 
             "min_samples_leaf":min_samples_leaf, 
             "bootstrap":bootstrap, 
            "max_features":max_features}

print(param_grid)
# Out:
# {'n_estimators': [100, 300, 500, 800, 1200], 'max_depth': [5, 8, 15, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10], 'bootstrap': [True, False], 'max_features': ['auto', 'sqrt']}

# %%
rf_grid=GridSearchCV(estimator=model,param_grid=param_grid,cv=3,n_jobs=-1,verbose=2)

# %%
#rf_grid.fit(X_res,y_res)

# %%
#rf_grid.best_params_

# %%
model_CV=RandomForestClassifier(n_estimators=800,max_depth=25, min_samples_split=2,min_samples_leaf=1,bootstrap=False,max_features='auto')

# %%
model_CV.fit(X_res,y_res)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=25, n_estimators=800)

# %% [markdown]
# ## Model Evaluation

# %%
y_pred_Ran_CV=model_CV.predict(X_test)

# %%
acc_score_ran=accuracy_score(y_test,y_pred_Ran_CV)

# %%
acc_score_ran
# Out:
# 0.7832258064516129

# %%
confusion_matrix(y_test,y_pred_Ran_CV)
# Out:
# array([[1473,  224],
#        [ 280,  348]], dtype=int64)

# %%
print(classification_report(y_test,y_pred_Ran_CV))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85      1697
#            1       0.61      0.55      0.58       628
#
#     accuracy                           0.78      2325
#    macro avg       0.72      0.71      0.72      2325
# weighted avg       0.78      0.78      0.78      2325

# %% [markdown]
# ## Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc_model=DecisionTreeClassifier()

# %%
dtc_model.fit(X_res,y_res)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dc=dtc_model.predict(X_test)

# %% [markdown]
# ## Model Evalation

# %%
confusion_matrix(y_test,y_pred_dc)
# Out:
# array([[1367,  330],
#        [ 280,  348]], dtype=int64)

# %%
acc_score_dc=accuracy_score(y_test,y_pred_dc)

# %%
acc_score_dc
# Out:
# 0.7376344086021506

# %%
print(classification_report(y_test,y_pred_dc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      1697
#            1       0.51      0.55      0.53       628
#
#     accuracy                           0.74      2325
#    macro avg       0.67      0.68      0.68      2325
# weighted avg       0.74      0.74      0.74      2325

# %%
## Hyperparameter tuning of Decision tree

# %%
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
grid_search_dc = GridSearchCV(estimator=dtc_model, param_grid=params,cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
#grid_search_dc.fit(X_res,y_res)

# %%
#grid_search_dc.best_params_

# %%
dtc_model_CV=DecisionTreeClassifier(max_depth=10,min_samples_leaf=10,criterion='gini')

# %%
dtc_model_CV.fit(X_res,y_res)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=10)

# %%
y_pred_dc_cv=dtc_model_CV.predict(X_test)

# %%
acc_score_dc_cv=accuracy_score(y_test,y_pred_dc_cv)

# %%
acc_score_dc_cv
# Out:
# 0.7561290322580645

# %%
print(classification_report(y_test,y_pred_dc_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82      1697
#            1       0.54      0.68      0.60       628
#
#     accuracy                           0.76      2325
#    macro avg       0.70      0.73      0.71      2325
# weighted avg       0.78      0.76      0.76      2325

# %%
## Auc and Roc Curves to select the best model

# %%
from sklearn.metrics import roc_curve,auc

# %%
#For logistic Regression without Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test, y_pred)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Logistic Regression Without Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Logistic Regression Without Hyperparmeter tuning')

# %%
#For logistic Regression with Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test, y_pred_CV)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Logistic Regression With Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Logistic Regression With Hyperparmeter tuning')

# %%
#For Random Forest without Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test,y_pred_Ran)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Random forest Without Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Random forest Without Hyperparmeter tuning')

# %%
#For Random Forest with Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test,y_pred_Ran_CV)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Random forest With Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Random forest With Hyperparmeter tuning')

# %%
#For Decision tree without Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test,y_pred_dc)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Decision tree Without Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Decision tree Without Hyperparmeter tuning')

# %%
#For Decision tree with Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test,y_pred_dc_cv)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Decision tree With Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Decision tree With Hyperparmeter tuning')

# %%
Conslution With the above graphs we can underSo the best model is Logistic Regression

# %% [markdown]
# ## Saving The model for future Use

# %%
import joblib
joblib.dump(Logi_reg, "Customer_Churn.pkl")
# Out:
# ['Customer_Churn.pkl']
