# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Understanding the dataset/EDA

# %%
df=pd.read_csv("E:\\Datatrained final Projects\\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df.shape # To know the shape of the dataset
# Out:
# (1470, 35)

# %% [markdown]
# Here we can see that there are 1450 rows and 35 colums

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info() # To check the datatypes, null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Here we can see that there are no null values

# %%
df.duplicated().sum()# To check the duplicates
# Out:
# 0

# %% [markdown]
# There are no duplicates

# %%
sns.countplot(df["Attrition"])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
#  Note: Here we can easily see that Attrition (yes ) is less when complared to (No)
#  This means less number of employess are leaving the organization

# %%
sns.countplot(df["BusinessTravel"])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
df["Attrition"].value_counts().plot(kind='pie',autopct='% 2f')
# Out:
# <AxesSubplot:ylabel='Attrition'>

# %% [markdown]
# Here we can note that Attrition % of No is 83.8 and Yes is 16,122

# %%
df["BusinessTravel"].value_counts().plot(kind='pie',autopct='% 2f')
# Out:
# <AxesSubplot:ylabel='BusinessTravel'>

# %% [markdown]
# Here we can note that 70 of employess have travel rarely

# %%
sns.countplot(df["Department"])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# Here we can note that most of the employess are from research and development department

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["EducationField"])
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# With the above graph we can know that most of the employess are from Life Sciences  and Medical field

# %%
sns.countplot(df["Gender"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# with the above graph we can note that most of employess are Male

# %%
plt.figure(figsize=(20,7),dpi=200)
sns.countplot(df["JobRole"])
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %% [markdown]
# With the above  graph  we can note that most of the employess are Sales Executive and Research Scientiest

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
sns.countplot(df["MaritalStatus"])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# With this we can easily know that most of the emplyoess are married

# %%
sns.countplot(df["OverTime"])
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# With this we can note that most of the employeess has overtime

# %%
sns.histplot(x="Age",data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# We can note that The age is between 18 to 60 of the emplyeess and most number of employees are between 25 to 40

# %%
df["Age"].max()
# Out:
# 60

# %%
df["Age"].min()
# Out:
# 18

# %%
sns.distplot(df[df["Attrition"]=='Yes']['Age'],hist=False)
sns.distplot(df[df["Attrition"]=='No']['Age'],hist=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# this means that employess with age around 30 is leaving the orgnanization when compared to employees with age around 50

# %%
sns.distplot(df[df["Attrition"]=='Yes']['DistanceFromHome'],hist=False)
sns.distplot(df[df["Attrition"]=='No']['DistanceFromHome'],hist=False)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Density'>

# %% [markdown]
# Here we can note that when the distance is more than 15 then Attrition == yes is more when compared to less distance

# %%
sns.histplot(x="EmployeeCount",data=df)
# Out:
# <AxesSubplot:xlabel='EmployeeCount', ylabel='Count'>

# %%
df["EmployeeCount"].value_counts()
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %% [markdown]
# With this we came to know that only one value is present in this column ie 1 which is of no use to us so we can drop this column

# %%
df["Over18"].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %% [markdown]
# With this we came to know tha all are above 18  years so we can drop this column

# %%
df["StandardHours"].value_counts()
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %% [markdown]
# So with this we came to know that standard hours for all the employess is 80 so this column is also not use full to us so we can drop this column

# %%
sns.histplot(x="DistanceFromHome",data=df)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Count'>

# %% [markdown]
# Here we can note that most the employees live near to the Company

# %%
sns.histplot(x="EmployeeNumber",data=df)
# Out:
# <AxesSubplot:xlabel='EmployeeNumber', ylabel='Count'>

# %%
df["EmployeeNumber"].value_counts() # Here we can note that employee number is the unique value So can drop this column
# Out:
# 1       1
# 1391    1
# 1389    1
# 1387    1
# 1383    1
#        ..
# 659     1
# 657     1
# 656     1
# 655     1
# 2068    1
# Name: EmployeeNumber, Length: 1470, dtype: int64

# %%
sns.countplot(df["EnvironmentSatisfaction"])
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %% [markdown]
# With this we can understand that Evironment satisfaction is categorial column with four categories 1,2,3,4

# %%
sns.countplot(df["JobInvolvement"])
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %% [markdown]
# With this we can understand that Jobinvolvement is having four Categories ie 1,2,3,4

# %%
sns.countplot(df["JobSatisfaction"])
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %% [markdown]
# With this we can understand that JobSatisfaction is categorial column with four categories 1,2,3,4

# %%
sns.displot(x="MonthlyIncome",data=df,kde=True)

# %% [markdown]
# We can note that most of the employees monthly income in the range 2500 to 3000

# %%
sns.displot(x="TotalWorkingYears",data=df,kde=True)

# %% [markdown]
# Here we can note that most of the  employess are 5 years of expirence

# %%
sns.displot(x="YearsAtCompany",data=df,kde=True)

# %% [markdown]
# Here we can note that most of the employees are new to the company

# %%
sns.displot(x="YearsInCurrentRole",data=df,kde=True)

# %% [markdown]
# Here we can note that most of the employees around 400 are in the same role since 2.5 years

# %%
sns.displot(x="YearsSinceLastPromotion",data=df,kde=True)

# %% [markdown]
# Here we can  note that most of the employees are getting promotion

# %%
sns.displot(x="YearsWithCurrManager",data=df,kde=True)
sns.displot(x="YearsInCurrentRole",data=df,kde=True)

# %% [markdown]
# ## Encoding The Target column

# %%
att_dumm=pd.get_dummies(df["Attrition"],drop_first=True)

# %%
df=pd.concat([df,att_dumm],axis=1)

# %%
df=df.drop(["Attrition"],axis=1)

# %%
sns.barplot(x="Gender",y="Yes",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Yes'>

# %% [markdown]
# With this we came to know the Male is been attrited more when compared to female

# %%
sns.barplot(x="BusinessTravel",y="Yes",data=df)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Yes'>

# %% [markdown]
# With this we came to know the Travel Frequently is been attrited more when compared to others

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        2  ...            80                 0
# ...

# %%
sns.barplot(x="Department",y="Yes",data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Yes'>

# %% [markdown]
# With this we came to know the Human Resources is been attrited more when compared to others

# %%
plt.figure(figsize=(15,7))
sns.barplot(x="EducationField",y="Yes",data=df)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='Yes'>

# %% [markdown]
# With this we came to know that the attrition rate was more in Human resource

# %% [markdown]
# ## Feature Engineering

# %%
df.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %% [markdown]
# So there are no missing values

# %% [markdown]
# ## Dropping the colums that are not useful

# %% [markdown]
# 1) EmployeeNumber 2)Over18 3) StandardHours  4)EmployeeNumber

# %%
df=df.drop(["EmployeeNumber",'Over18','StandardHours',"EmployeeCount"],axis=1)

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  ...  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female          94  ...                         1                 0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1470 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobLevel                  1470 non-null   int64
#  12  JobRole                   1470 non-null   object
#  13  JobSatisfaction           1470 non-null   int64
# ...

# %%
corr_=df.corr()

# %%
plt.figure(figsize=(17,17),dpi=200)
sns.heatmap(data=corr_,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Verifying the multicollinearity so that we drop the columnn

# %%
 sns.scatterplot(x="YearsAtCompany",y="YearsWithCurrManager",data=df)
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='YearsWithCurrManager'>

# %%
 sns.scatterplot(x="YearsAtCompany",y="YearsInCurrentRole",data=df)
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='YearsInCurrentRole'>

# %% [markdown]
# Here we can see that as years at company is incresing the Years with current Manager is also increasing so we can drop Years with current Manager and we can also the same graph with Years in current Role  so we can drop this also

# %%
df=df.drop(["YearsInCurrentRole","YearsWithCurrManager"],axis=1)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
df.shape
# Out:
# (1470, 29)

# %% [markdown]
# ## Handling Categorical Values

# %% [markdown]
# Below are the categorical values
#  1)BusinessTravel 2)Department 3) EducationField 4) Gender 5) JobRole 6) MaritalStatus 7) OverTime

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    else:
        df[column]=LabelEncoder().fit_transform(df[column])

# %%
df.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   23               2        624           2                 0          1
# 1   31               1        113           1                 7          0
# 2   19               2        805           1                 1          1
# 3   15               1        820           1                 2          3
# 4    9               2        312           1                 1          0
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0               1                        1       0          64  ...
# 1               1                        2       1          31  ...
# 2               4                        3       1          62  ...
# 3               1                        3       0          26  ...
# 4               3                        0       1          10  ...
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   int32
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   int32
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   int32
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1470 non-null   int32
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobLevel                  1470 non-null   int64
#  12  JobRole                   1470 non-null   int32
#  13  JobSatisfaction           1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  BusinessTravel    DailyRate   Department  \
# count  1470.000000     1470.000000  1470.000000  1470.000000
# mean     18.923810        1.607483   443.074830     1.260544
# std       9.135373        0.665455   253.513199     0.527792
# min       0.000000        0.000000     0.000000     0.000000
# 25%      12.000000        1.000000   225.000000     1.000000
# 50%      18.000000        2.000000   447.000000     1.000000
# 75%      25.000000        2.000000   660.000000     2.000000
# max      42.000000        2.000000   885.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EnvironmentSatisfaction  \
# count       1470.000000  1470.000000     1470.000000              1470.000000
# mean           8.192517     1.912925        2.247619                 1.721769
# std            8.106864     1.024165        1.331369                 1.093082
# min            0.000000     0.000000        0.000000                 0.000000
# ...

# %%
df.skew().sort_values(ascending=False)
# Out:
# YearsSinceLastPromotion     1.984290
# PerformanceRating           1.921883
# Yes                         1.844366
# YearsAtCompany              1.676650
# TotalWorkingYears           1.112899
# NumCompaniesWorked          1.026471
# JobLevel                    1.025401
# StockOptionLevel            0.968980
# OverTime                    0.964489
# DistanceFromHome            0.958118
# PercentSalaryHike           0.821128
# TrainingTimesLastYear       0.553124
# EducationField              0.550371
# Age                         0.413286
# Department                  0.172231
# MonthlyIncome               0.060816
# MonthlyRate                 0.012315
# DailyRate                   0.000930
# HourlyRate                 -0.032311
# MaritalStatus              -0.152175
# Education                  -0.289681
# RelationshipSatisfaction   -0.302828
# EnvironmentSatisfaction    -0.321654
# JobSatisfaction            -0.329672
# JobRole                    -0.357270
# ...

# %% [markdown]
# So we have removed Categorial varaibles

# %% [markdown]
# ## Checking the Outliers

# %%
collist=df.columns.values

# %%
ncol=6
nrow=6
plt.figure(figsize=(5*nrow,6*ncol),dpi=300)
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient="v")

# %% [markdown]
# So there are many outliers in Total working Years,Yearsatcompnay ,Years in current role Years sinnce last Promotion

# %% [markdown]
# # Removing Outliers

# %%
#1st quantile
q1=df.quantile(0.25)

# %%
#3rd quantile
q3=df.quantile(0.75)

# %%
#IQR
IQR=q3-q1

# %%
TotalWorkingYears_high=q3.TotalWorkingYears+1.5*IQR.TotalWorkingYears

# %%
TotalWorkingYears_high
# Out:
# 28.5

# %%
index=np.where(df['TotalWorkingYears']>TotalWorkingYears_high)
index
# Out:
# (array([  18,   62,   85,   98,  105,  126,  187,  190,  233,  237,  270,
#          379,  401,  408,  411,  424,  445,  473,  477,  534,  552,  561,
#          588,  595,  616,  624,  627,  649,  653,  677,  714,  743,  749,
#          760,  766,  774,  867,  890,  894,  914,  918,  956,  962,  966,
#          971,  976, 1008, 1009, 1010, 1043, 1054, 1086, 1111, 1116, 1138,
#         1181, 1184, 1194, 1264, 1301, 1331, 1374, 1401], dtype=int64),)

# %%
df=df.drop(df.index[index])

# %%
df.reset_index(inplace = True, drop = True)

# %%
Yearsatcompany_high=q3.YearsAtCompany+1.5*IQR.YearsAtCompany

# %%
Yearsatcompany_high
# Out:
# 18.0

# %%
index=np.where(df['TotalWorkingYears']>Yearsatcompany_high)
index
# Out:
# (array([  24,   27,   28,   32,   44,   49,   61,   63,   65,   68,   80,
#           87,   90,  101,  105,  107,  114,  118,  136,  141,  144,  147,
#          159,  169,  172,  180,  182,  186,  210,  223,  226,  234,  241,
#          247,  253,  258,  268,  269,  270,  275,  279,  284,  289,  293,
#          296,  300,  303,  305,  315,  318,  321,  356,  364,  378,  379,
#          380,  388,  393,  395,  397,  402,  409,  411,  412,  413,  415,
#          431,  441,  448,  449,  470,  473,  478,  504,  507,  513,  514,
#          515,  518,  524,  535,  546,  562,  569,  585,  619,  645,  656,
#          669,  671,  676,  677,  685,  690,  697,  704,  705,  707,  710,
#          714,  715,  717,  718,  720,  722,  735,  742,  748,  751,  753,
#          763,  768,  774,  777,  778,  785,  801,  802,  815,  822,  825,
#          832,  838,  850,  859,  860,  865,  868,  874,  876,  878,  881,
#          885,  895,  896,  904,  910,  913,  914,  930,  948,  949,  953,
# ...

# %%
df=df.drop(df.index[index])

# %%
df.reset_index(inplace = True, drop = True)

# %%
df.shape
# Out:
# (1211, 29)

# %%
Yearssincelast_high=q3.YearsSinceLastPromotion+1.5*IQR.YearsSinceLastPromotion
Yearssincelast_high
# Out:
# 7.5

# %%
index=np.where(df['YearsSinceLastPromotion']>Yearssincelast_high)
index
# Out:
# (array([  15,   40,   48,   54,   55,   74,  174,  223,  224,  256,  260,
#          266,  272,  319,  321,  330,  360,  410,  411,  416,  422,  572,
#          577,  603,  616,  641,  715,  773,  778,  782,  792,  836,  859,
#          882,  943,  988,  992,  994, 1142, 1158, 1173, 1189, 1191],
#        dtype=int64),)

# %%
df=df.drop(df.index[index])

# %%
df.reset_index(inplace = True, drop = True)

# %%
df.shape
# Out:
# (1168, 29)

# %%
ncol=6
nrow=6
plt.figure(figsize=(5*nrow,6*ncol),dpi=300)
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient="v")

# %%
Age_high=q3.Age+1.5*IQR.Age
Age_high
# Out:
# 44.5

# %%
index=np.where(df['Age']>Age_high)
index
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# So We can removed outliers

# %% [markdown]
# ## Feature Scaling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1168 non-null   int64
#  1   BusinessTravel            1168 non-null   int32
#  2   DailyRate                 1168 non-null   int64
#  3   Department                1168 non-null   int32
#  4   DistanceFromHome          1168 non-null   int64
#  5   Education                 1168 non-null   int64
#  6   EducationField            1168 non-null   int32
#  7   EnvironmentSatisfaction   1168 non-null   int64
#  8   Gender                    1168 non-null   int32
#  9   HourlyRate                1168 non-null   int64
#  10  JobInvolvement            1168 non-null   int64
#  11  JobLevel                  1168 non-null   int64
#  12  JobRole                   1168 non-null   int32
#  13  JobSatisfaction           1168 non-null   int64
# ...

# %%
X=df.drop("Yes",axis=1)

# %%
y=df["Yes"]

# %%
X.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   23               2        624           2                 0          1
# 1   31               1        113           1                 7          0
# 2   19               2        805           1                 1          1
# 3   15               1        820           1                 2          3
# 4    9               2        312           1                 1          0
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  OverTime  \
# 0               1                        1       0          64  ...         1
# 1               1                        2       1          31  ...         0
# 2               4                        3       1          62  ...         1
# 3               1                        3       0          26  ...         1
# 4               3                        0       1          10  ...         0
#
# ...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Yes, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
X_scalar=scalar.fit_transform(X)

# %% [markdown]
# ## Performing train test split

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X_scalar, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
Logi_reg=LogisticRegression()

# %%
Logi_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=Logi_reg.predict(X_test)

# %% [markdown]
# ## Logistic Regression Model Evaluation

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[302,  17],
#        [ 37,  30]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       319
#            1       0.64      0.45      0.53        67
#
#     accuracy                           0.86       386
#    macro avg       0.76      0.70      0.72       386
# weighted avg       0.85      0.86      0.85       386

# %%
logi_accuracy=accuracy_score(y_test, y_pred)

# %%
logi_accuracy
# Out:
# 0.8601036269430051

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(Logi_reg,X_scalar,y,cv=5).mean()
# Out:
# 0.8655955394152819

# %% [markdown]
# ## Hyperparmater Tuning of Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [    
    {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }
]

# %%
clf = GridSearchCV(Logi_reg, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
best_clf=clf.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits

# %%
clf.best_params_
# Out:
# {'C': 0.23357214690901212,
#  'max_iter': 100,
#  'penalty': 'l2',
#  'solver': 'liblinear'}

# %%
Logi_reg_CV=LogisticRegression(C=0.23357214690901212,max_iter=100,penalty="l2",solver='liblinear')

# %%
Logi_reg_CV.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.23357214690901212, solver='liblinear')

# %%
y_pred_CV=Logi_reg_CV.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
confusion_matrix(y_test, y_pred_CV)
# Out:
# array([[302,  17],
#        [ 38,  29]], dtype=int64)

# %%
print(classification_report(y_test, y_pred_CV))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       319
#            1       0.63      0.43      0.51        67
#
#     accuracy                           0.86       386
#    macro avg       0.76      0.69      0.71       386
# weighted avg       0.84      0.86      0.85       386

# %%
logi_accuracy_CV=accuracy_score(y_test, y_pred_CV)

# %% [markdown]
# Accuracy After Hyperparmeter tuning

# %%
logi_accuracy_CV
# Out:
# 0.8575129533678757

# %% [markdown]
# So After Hyperparameter we are getting almost same accuracy so will go with the model without Hyperparameter tuning

# %% [markdown]
# # Random Forest Classfier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_Ran=model.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
confusion_matrix(y_test,y_pred_Ran)
# Out:
# array([[316,   3],
#        [ 51,  16]], dtype=int64)

# %%
print(classification_report(y_test,y_pred_Ran))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       319
#            1       0.84      0.24      0.37        67
#
#     accuracy                           0.86       386
#    macro avg       0.85      0.61      0.65       386
# weighted avg       0.86      0.86      0.83       386

# %%
model_acc=accuracy_score(y_test,y_pred_Ran)

# %%
model_acc
# Out:
# 0.8601036269430051

# %%
cross_val_score(model,X_scalar,y,cv=5).mean()
# Out:
# 0.8416052235794724

# %% [markdown]
# So Cross validation score is almost similar to the model

# %% [markdown]
# ## Hyperparmaeter tuning of Random forest

# %%
n_estimators = [100, 300, 500, 800, 1200]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100]
max_features=["auto","sqrt"]
bootstrap=[True,False]
min_samples_leaf = [1, 2, 5, 10]

# %%
param_grid ={"n_estimators":n_estimators,
              "max_depth": max_depth,  
              "min_samples_split":min_samples_split, 
             "min_samples_leaf":min_samples_leaf, 
             "bootstrap":bootstrap, 
            "max_features":max_features}

print(param_grid)
# Out:
# {'n_estimators': [100, 300, 500, 800, 1200], 'max_depth': [5, 8, 15, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10], 'bootstrap': [True, False], 'max_features': ['auto', 'sqrt']}

# %%
rf_grid=GridSearchCV(estimator=model,param_grid=param_grid,cv=3,n_jobs=-1,verbose=2)

# %%
#rf_grid.fit(X_train,y_train)

# %%
#rf_grid.best_params_

# %%
model_CV=RandomForestClassifier(n_estimators=100,max_depth=15, min_samples_split=2,min_samples_leaf=1,bootstrap=False,max_features='auto')

# %%
model_CV.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=15)

# %% [markdown]
# ## Model Evaluation

# %%
y_pred_Ran_CV=model_CV.predict(X_test)

# %%
acc_score_ran=accuracy_score(y_pred_Ran_CV,y_test)

# %%
acc_score_ran
# Out:
# 0.8497409326424871

# %%
confusion_matrix(y_pred_Ran_CV,y_test)
# Out:
# array([[311,  50],
#        [  8,  17]], dtype=int64)

# %%
print(classification_report(y_pred_Ran_CV,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91       361
#            1       0.25      0.68      0.37        25
#
#     accuracy                           0.85       386
#    macro avg       0.61      0.77      0.64       386
# weighted avg       0.93      0.85      0.88       386

# %% [markdown]
# So Model Accuracy has been impoved using Hyperparameter tuning

# %% [markdown]
# ## Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc_model=DecisionTreeClassifier()

# %%
dtc_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dc=dtc_model.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
acc_score_dc=accuracy_score(y_pred_dc,y_test)

# %%
acc_score_dc
# Out:
# 0.7590673575129534

# %%
print(classification_report(y_pred_dc,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       302
#            1       0.43      0.35      0.38        84
#
#     accuracy                           0.76       386
#    macro avg       0.63      0.61      0.62       386
# weighted avg       0.74      0.76      0.75       386

# %% [markdown]
# ## Hyperparameter tuning of Decision tree

# %%
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
grid_search_dc = GridSearchCV(estimator=dtc_model, param_grid=params,cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
grid_search_dc.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
grid_search_dc.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10}

# %%
dtc_model_CV=DecisionTreeClassifier(max_depth=3,min_samples_leaf=10,criterion='entropy')

# %%
dtc_model_CV.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=10)

# %% [markdown]
# ## Model Evaluation

# %%
y_pred_dc_cv=dtc_model_CV.predict(X_test)

# %%
acc_score_dc_cv=accuracy_score(y_pred_dc_cv,y_test)

# %%
acc_score_dc_cv
# Out:
# 0.8341968911917098

# %%
print(classification_report(y_pred_dc_cv,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90       353
#            1       0.27      0.55      0.36        33
#
#     accuracy                           0.83       386
#    macro avg       0.61      0.70      0.63       386
# weighted avg       0.89      0.83      0.86       386

# %% [markdown]
# Accuracy has improved after hyperparameter tuning but still less than Random forest and Logistic regression

# %% [markdown]
# ## Auc and Roc Curves to select the best model

# %%
from sklearn.metrics import roc_curve,auc

# %%
#For logistic Regression without Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test, y_pred)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Logistic Regression Without Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Logistic Regression Without Hyperparmeter tuning')

# %%
#For logistic Regression with Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test, y_pred_CV)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Logistic Regression With Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Logistic Regression With Hyperparmeter tuning')

# %%
#For Random Forest without Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_test,y_pred_Ran)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Random forest Without Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Random forest Without Hyperparmeter tuning')

# %%
#For Random Forest with Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_pred_Ran_CV,y_test)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Random forest With Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Random forest With Hyperparmeter tuning')

# %%
#For Decision tree without Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_pred_dc,y_test)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Decision tree Without Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Decision tree Without Hyperparmeter tuning')

# %%
#For Decision tree with Hyperparmeter tuning
fpr,tpr,thesholds=roc_curve(y_pred_dc_cv,y_test)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='orange',label='Roc curve(area = %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',linestyle='--' )
plt.legend(loc='lower right')
plt.title("Decision tree With Hyperparmeter tuning")
# Out:
# Text(0.5, 1.0, 'Decision tree With Hyperparmeter tuning')

# %% [markdown]
# ## Here we can see that Random forest with Hyperparameter tuning is performing well when compared to other algorithims

# %% [markdown]
# # Saving the model for future use

# %%
import pickle

# %%
filename = 'finalized_model.sav'
pickle.dump(model_CV, open(filename, 'wb'))
